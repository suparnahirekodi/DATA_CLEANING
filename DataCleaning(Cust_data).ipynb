# %% [markdown]
# #### Data Cleaning in pandas
#
# * Check for any duplicates and if any remove them
# * standardize data and fix errors

# %%
import pandas as pd

# %%
! pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.9 kB 660.6 kB/s eta 0:00:01
#    ----------- --------------------------- 71.7/250.9 kB 975.2 kB/s eta 0:00:01
#    ---------------------------------------  245.8/250.9 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 1.7 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\klemp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df=pd.read_excel("Data sets/ccl.xlsx")

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
fd=df.duplicated()

# %%
fd
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# dtype: bool

# %%
df.iloc[20]
# Out:
# CustomerID                                  1020
# First_Name                                Anakin
# Last_Name                              Skywalker
# Phone_Number                        876|678|3469
# Address              910 Tatooine Road, Tatooine
# Paying Customer                              Yes
# Do_Not_Contact                                 N
# Not_Useful_Column                           True
# Name: 20, dtype: object

# %%
df.tail(5)
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 16        1017   Michael       Scott  123/643/9775
# 17        1018      Clark       Kent    7066950392
# 18        1019      Creed     Braton           N/a
# 19        1020     Anakin  Skywalker  876|678|3469
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                            Address Paying Customer Do_Not_Contact  \
# 16  121 Paper Avenue, Pennsylvania             Yes             No
# 17                 3498 Super Lane               Y            NaN
# 18                             N/a             N/a            Yes
# 19     910 Tatooine Road, Tatooine             Yes              N
# 20     910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 16              False
# 17               True
# 18               True
# 19               True
# 20               True

# %%
df[fd]
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 20               True

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# > step 2

# %%
df.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column'],
#       dtype='str')

# %%
df['Last_Name']
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: str

# %%
df['Last_Name'].str.strip("123._/") # regular expression to remove unwanted characters
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Schrute
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        Gamgee
# 11        Potter
# 12        Draper
# 13         Knope
# 14    Flenderson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: str

# %%
df['Last_Name']=df['Last_Name'].str.strip("123._/")

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df['Phone_Number']

# %%
# steps to make all numbers in the phone number coulumn to be of same length and format
#step1-replace all the unwanted-characters to empty string("")

# %%
#python string
name = "mike-tyson"
type(name)
name.replace("-","/")

# %%
df['Phone_Number'].str.replace("[^0-9]","",regex=True)

# %%
# lambda funcation
lambda x:x[0:3]+"-"+x[3:6]+"-"+x[6:10]
l1("1234567890")

# %% [markdown]
# ### apply()->Apply is a pandas funcations which will apply specified functionality to each value of series

# %%
df['Phone_Number']=df['Phone_Number'].apply(lambda x:str(x))

# %%
 df['Phone_Number']

# %%
df['Phone_Number']=df['Phone_Number'].apply(lambda x:str(x))

# %%
df['Phone_Number']=df['Phone_Number'].str.replace("[^0-9]","",regex=True)

# %%
df['Phone_Number']
